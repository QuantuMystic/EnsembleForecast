# %%
# libraries for the files in google drive
from pydrive.auth import GoogleAuth
from google.colab import drive
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import pandas as pd


link = 'https://drive.google.com/file/d/193ND4XKmMSnqdOlbDGP36b5V5s6HcQJb/view'
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

id = link.split("/")[-2]

download = drive.CreateFile({'id': id})


download.GetContentFile('adult.csv')
df  = pd.read_csv("adult.csv")
df.head()
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3            Cuba   <=50K
# 4   United-States   <=50K

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.model_selection import GridSearchCV

# %%
df.duplicated().sum()
# df.isnull().sum()
# Out:
# 24

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (32536, 15)

# %%
df
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0         Exec-managerial         Husband   White     Male      0   0   13
# 1       Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2       Handlers-cleaners         Husband   Black     Male      0   0   40
# 3          Prof-specialty            Wife   Black   Female      0   0   40
# 4         Exec-managerial            Wife   White   Female      0   0   40
# ...                   ...             ...     ...      ...    ...  ..  ...
# 32555        Tech-support            Wife   White   Female      0   0   38
# 32556   Machine-op-inspct         Husband   White     Male      0   0   40
# 32557        Adm-clerical       Unmarried   White   Female      0   0   40
# 32558        Adm-clerical       Own-child   White     Male      0   0   20
# 32559     Exec-managerial            Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 0       United-States   <=50K
# 1       United-States   <=50K
# 2       United-States   <=50K
# 3                Cuba   <=50K
# 4       United-States   <=50K
# ...               ...     ...
# 32555   United-States   <=50K
# 32556   United-States    >50K
# 32557   United-States   <=50K
# 32558   United-States   <=50K
# 32559   United-States    >50K
#
# [32536 rows x 15 columns]

# %%
cat_feat = df.select_dtypes(include=['object']).columns
cat_feat
# Out:
# Index([' State-gov', ' Bachelors', ' Never-married', ' Adm-clerical',
#        ' Not-in-family', ' White', ' Male', ' United-States', ' <=50K'],
#       dtype='object')

# %%
head = ['Age','Workclass','Fnlwgt','Education','education_num','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week','native_country','income']
df.to_csv("adultheader.csv", header=head, index=False)
df2 = pd.read_csv("adultheader.csv")
print(df2)
# Out:
#        Age          Workclass  Fnlwgt    Education  education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32531   27            Private  257302   Assoc-acdm             12
# 32532   40            Private  154374      HS-grad              9
# 32533   58            Private  151910      HS-grad              9
# 32534   22            Private  201490      HS-grad              9
# 32535   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32531   Married-civ-spouse        Tech-support            Wife   White
# 32532   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32533              Widowed        Adm-clerical       Unmarried   White
# 32534        Never-married        Adm-clerical       Own-child   White
# 32535   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32531   Female             0             0              38   United-States
# 32532     Male             0             0              40   United-States
# 32533   Female             0             0              40   United-States
# 32534     Male             0             0              20   United-States
# 32535   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32531   <=50K
# 32532    >50K
# 32533   <=50K
# 32534   <=50K
# 32535    >50K
#
# [32536 rows x 15 columns]

# %%
print(f"Ratio above 50k : {(df2['income'] == ' >50K').astype('int').sum() / df.shape[0] * 100 :.2f}%")
# Out:
# Ratio above 50k : 24.09%

# %%
num_feat = df2.select_dtypes(include=['int64']).columns
num_feat
# Out:
# Index(['Age', 'Fnlwgt', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week'],
#       dtype='object')

# %%
plt.figure(1, figsize=(16,10))
sns.pairplot(data=df2, hue='sex')
plt.show()

# %%
nb_female = (df2.sex == ' Female').astype('int').sum()
nb_male = (df2.sex == ' Male').astype('int').sum()
nb_female, nb_male
# Out:
# (10762, 21774)

# %%
plt.figure(figsize=(18,10))
plt.subplot(231)

i=0
for c in num_feat:
    plt.subplot(2, 3, i+1)
    i += 1
    sns.kdeplot(df2[df2['sex'] == ' Female'][c], shade=True)
    sns.kdeplot(df2[df2['sex'] == ' Male'][c], shade=False)
    plt.title(c)

plt.show()
# Out:
# <ipython-input-12-3087ab078fad>:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Female'][c], shade=True)
# <ipython-input-12-3087ab078fad>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Male'][c], shade=False)
# <ipython-input-12-3087ab078fad>:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Female'][c], shade=True)
# <ipython-input-12-3087ab078fad>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Male'][c], shade=False)
# <ipython-input-12-3087ab078fad>:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Female'][c], shade=True)
# <ipython-input-12-3087ab078fad>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Male'][c], shade=False)
# <ipython-input-12-3087ab078fad>:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Female'][c], shade=True)
# <ipython-input-12-3087ab078fad>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Male'][c], shade=False)
# <ipython-input-12-3087ab078fad>:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Female'][c], shade=True)
# <ipython-input-12-3087ab078fad>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Male'][c], shade=False)
# <ipython-input-12-3087ab078fad>:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Female'][c], shade=True)
# <ipython-input-12-3087ab078fad>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2[df2['sex'] == ' Male'][c], shade=False)

# %%
# plt.figure(figsize=(18,25))
# plt.subplot(521)

# i=0
# for c in cat_feat:
#     plt.subplot(5, 2, i+1)
#     i += 1
#     sns.countplot(x=c, data=df2, hue='sex')
#     plt.title(c)

# plt.show()

# %%
nb_male_above = len(df2[(df2.income == ' >50K') & (df2.sex == ' Male')])
nb_male_below = len(df2[(df2.income == ' <=50K') & (df2.sex == ' Male')])
nb_female_above = len(df2[(df2.income == ' >50K') & (df2.sex == ' Female')])
nb_female_below = len(df2[(df2.income == ' <=50K') & (df2.sex == ' Female')])
nb_male_above, nb_male_below, nb_female_above, nb_female_below
# Out:
# (6660, 15114, 1179, 9583)

# %%
print(nb_male_above)
print(nb_male)
# Out:
# 6660
# 21774

# %%
print(f'Among Males   : {(nb_male_above/nb_male)*100:.0f}% earn >50K // {(nb_male_below/nb_male)*100:.0f}% earn <=50K')
print(f'Among Females : {(nb_female_above/nb_female)*100:.0f}% earn >50K // {(nb_female_below/nb_female)*100:.0f}% earn <=50K')
# Out:
# Among Males   : 31% earn >50K // 69% earn <=50K
# Among Females : 11% earn >50K // 89% earn <=50K

# %%
nb_male_above /= nb_male
nb_male_below /= nb_male
nb_female_above /= nb_female
nb_female_below /= nb_female
nb_male_above, nb_male_below, nb_female_above, nb_female_below
# Out:
# (0.30586938550564896,
#  0.6941306144943511,
#  0.1095521278572756,
#  0.8904478721427244)

# %%
print(f'Among people earning >50K  : {nb_male_above / (nb_male_above + nb_female_above) *100 :.0f}% are Females and {nb_female_above / (nb_male_above + nb_female_above) *100 :.0f}% are Males')
print(f'Among people earning =<50K : {nb_male_below / (nb_male_below + nb_female_below) *100 :.0f}% are Females and {nb_female_below / (nb_male_below + nb_female_below) *100 :.0f}% are Males')
# Out:
# Among people earning >50K  : 74% are Females and 26% are Males
# Among people earning =<50K : 44% are Females and 56% are Males

# %%
df2['US native'] = (df2['native_country'] == ' United-States').astype('int')
plt.figure(figsize=(6,4))
sns.countplot(x='US native', data=df2, hue='sex')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='income', data=df2, hue='US native')
plt.show()

# %%
nb_native_above = len(df2[(df2.income == ' >50K') & (df2['US native'] == 1)])
nb_native_below = len(df2[(df2.income == ' <=50K') & (df2['US native'] == 1)])
nb_foreign_above = len(df2[(df2.income == ' >50K') & (df2['US native'] == 0)])
nb_foreign_below = len(df2[(df2.income == ' <=50K') & (df2['US native'] == 0)])
nb_native_above, nb_native_below, nb_foreign_above, nb_foreign_below
# Out:
# (7169, 21983, 670, 2714)

# %%
nb_native = (df2['US native'] == 1).astype('int').sum()
nb_foreign = df2.shape[0] - nb_native
nb_native, nb_foreign
# Out:
# (29152, 3384)

# %%
print(f'Among natives    : {(nb_native_above/nb_native)*100:.0f}% earn >50K // {(nb_native_below/nb_native)*100:.0f}% earn <=50K')
print(f'Among foreigners : {(nb_foreign_above/nb_foreign)*100:.0f}% earn >50K // {(nb_foreign_below/nb_foreign)*100:.0f}% earn <=50K')
# Out:
# Among natives    : 25% earn >50K // 75% earn <=50K
# Among foreigners : 20% earn >50K // 80% earn <=50K

# %%
nb_native_above /= nb_native
nb_native_below /= nb_native
nb_foreign_above /= nb_foreign
nb_foreign_below /= nb_foreign
nb_native_above, nb_native_below, nb_foreign_above, nb_foreign_below
# Out:
# (0.24591794731064764,
#  0.7540820526893524,
#  0.1979905437352246,
#  0.8020094562647754)

# %%
print(f'Among people earning >50K  : {nb_native_above / (nb_native_above + nb_foreign_above) *100 :.0f}% are natives and {nb_foreign_above / (nb_native_above + nb_foreign_above) *100 :.0f}% are foreigners')
print(f'Among people earning =<50K : {nb_native_below / (nb_native_below + nb_foreign_below) *100 :.0f}% are natives and {nb_foreign_below / (nb_native_below + nb_foreign_below) *100 :.0f}% are foreigners')
# Out:
# Among people earning >50K  : 55% are natives and 45% are foreigners
# Among people earning =<50K : 48% are natives and 52% are foreigners

# %%
num_feat = df2.select_dtypes(include=['float', 'int']).columns
num_feat
# Out:
# Index(['Age', 'Fnlwgt', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week', 'US native'],
#       dtype='object')

# %%
sns.set(style="white")

corr = df2[num_feat].corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True


f, ax = plt.subplots(figsize=(7, 6))


cmap = sns.diverging_palette(220, 10, as_cmap=True)


sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .5})
# Out:
# <ipython-input-23-1427ad5be990>:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)
# <Axes: >

# %%
df2['income'] = pd.get_dummies(df2['income'], prefix='income', drop_first=True)

# %%
y = df2.income
df2 = df2.drop(columns=['income'])

# %%
print(f'Ratio above 50k:  {y.sum()/len(y)*100:.2f}%')
# Out:
# Ratio above 50k:  24.09%

# %%
df2.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital_status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  US native
# 0             0             0              13   United-States          1
# 1             0             0              40   United-States          1
# 2             0             0              40   United-States          1
# 3             0             0              40            Cuba          0
# 4             0             0              40   United-States          1

# %%
cols = list(df2.columns)
cols
# Out:
# ['Age',
#  'Workclass',
#  'Fnlwgt',
#  'Education',
#  'education_num',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_week',
#  'native_country',
#  'US native']

# %%
selected_feat = cols.copy()
selected_feat.remove('US native')
selected_feat
# Out:
# ['Age',
#  'Workclass',
#  'Fnlwgt',
#  'Education',
#  'education_num',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_week',
#  'native_country']

# %%
df2_final = df2[selected_feat]

# %%
cat_feat = df2_final.select_dtypes(include=['object']).columns
X = pd.get_dummies(df2_final[cat_feat], drop_first=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
def print_score(model, name):
    model.fit(X_train, y_train)
    print('Accuracy score of the', name, f': on train = {model.score(X_train, y_train)*100:.2f}%, on test = {model.score(X_test, y_test)*100:.2f}%')

# %%
print_score(LogisticRegression(),'LogisticReg')
# Out:
# Accuracy score of the LogisticReg : on train = 83.20%, on test = 83.56%
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#Decision Tree

print_score(DecisionTreeClassifier(), 'DecisionTreeClf')
# Out:
# Accuracy score of the DecisionTreeClf : on train = 86.67%, on test = 81.85%

# %%
rf = RandomForestClassifier().fit(X_train, y_train)
print(f'Accuracy score of the RandomForrest: on train = {rf.score(X_train, y_train)*100:.2f}%, on test = {rf.score(X_test, y_test)*100:.2f}%')
# Out:
# Accuracy score of the RandomForrest: on train = 86.67%, on test = 82.67%

# %%
print_score(DecisionTreeClassifier(), 'ExtraTreesClf')
# Out:
# Accuracy score of the ExtraTreesClf : on train = 86.67%, on test = 81.81%

# %%
features = X.columns
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]
num_features = len(importances)

# Plot the feature importances of the tree
plt.figure(figsize=(16, 4))
plt.title("Feature importances")
plt.bar(range(num_features), importances[indices], color="g", align="center")
plt.xticks(range(num_features), [features[i] for i in indices], rotation='vertical')
plt.xlim([-1, num_features])
plt.show()

# Print values
for i in indices:
    print ("{0} - {1:.3f}".format(features[i], importances[i]))
# Out:
# marital_status_ Married-civ-spouse - 0.184
# marital_status_ Never-married - 0.071
# occupation_ Exec-managerial - 0.052
# occupation_ Prof-specialty - 0.045
# sex_ Male - 0.045
# Education_ Bachelors - 0.043
# Education_ Masters - 0.032
# relationship_ Not-in-family - 0.030
# relationship_ Own-child - 0.028
# Education_ Prof-school - 0.024
# Education_ HS-grad - 0.023
# Workclass_ Private - 0.021
# native_country_ United-States - 0.017
# Education_ Doctorate - 0.017
# Workclass_ Self-emp-not-inc - 0.017
# occupation_ Other-service - 0.017
# Education_ Some-college - 0.016
# relationship_ Wife - 0.015
# race_ White - 0.015
# relationship_ Unmarried - 0.015
# Workclass_ Self-emp-inc - 0.015
# occupation_ Sales - 0.013
# Workclass_ Local-gov - 0.012
# Workclass_ Federal-gov - 0.012
# occupation_ Craft-repair - 0.011
# race_ Black - 0.011
# Workclass_ State-gov - 0.011
# occupation_ Adm-clerical - 0.010
# Education_ Assoc-voc - 0.010
# Education_ Assoc-acdm - 0.009
# occupation_ Tech-support - 0.009
# occupation_ Farming-fishing - 0.008
# Education_ 11th - 0.008
# marital_status_ Widowed - 0.007
# race_ Asian-Pac-Islander - 0.007
# occupation_ Machine-op-inspct - 0.007
# Education_ 7th-8th - 0.007
# relationship_ Other-relative - 0.007
# occupation_ Transport-moving - 0.007
# occupation_ Handlers-cleaners - 0.007
# marital_status_ Separated - 0.006
# occupation_ Protective-serv - 0.006
# native_country_ Mexico - 0.006
# Education_ 9th - 0.005
# marital_status_ Married-spouse-absent - 0.004
# Education_ 12th - 0.004
# native_country_ Germany - 0.003
# native_country_ Canada - 0.003
# native_country_ Philippines - 0.003
# race_ Other - 0.003
# native_country_ England - 0.003
# Education_ 5th-6th - 0.003
# native_country_ Italy - 0.002
# native_country_ South - 0.002
# native_country_ India - 0.002
# native_country_ Japan - 0.002
# Education_ 1st-4th - 0.002
# native_country_ Cuba - 0.002
# native_country_ Puerto-Rico - 0.002
# native_country_ Poland - 0.002
# native_country_ China - 0.001
# native_country_ Iran - 0.001
# native_country_ Jamaica - 0.001
# native_country_ Greece - 0.001
# native_country_ El-Salvador - 0.001
# native_country_ Taiwan - 0.001
# marital_status_ Married-AF-spouse - 0.001
# native_country_ France - 0.001
# native_country_ Vietnam - 0.001
# native_country_ Ireland - 0.001
# native_country_ Columbia - 0.001
# native_country_ Dominican-Republic - 0.001
# native_country_ Ecuador - 0.001
# native_country_ Cambodia - 0.001
# native_country_ Portugal - 0.001
# native_country_ Yugoslavia - 0.001
# native_country_ Hungary - 0.001
# native_country_ Haiti - 0.001
# native_country_ Guatemala - 0.000
# occupation_ Priv-house-serv - 0.000
# native_country_ Laos - 0.000
# native_country_ Nicaragua - 0.000
# native_country_ Hong - 0.000
# native_country_ Scotland - 0.000
# native_country_ Peru - 0.000
# Education_ Preschool - 0.000
# native_country_ Trinadad&Tobago - 0.000
# Workclass_ Without-pay - 0.000
# native_country_ Thailand - 0.000
# native_country_ Outlying-US(Guam-USVI-etc) - 0.000
# occupation_ Armed-Forces - 0.000
# native_country_ Honduras - 0.000
# Workclass_ Never-worked - 0.000
# native_country_ Holand-Netherlands - 0.000
